# %%
# Import dependencies
import numpy as np
import pandas as pd

# %%
# read the data file
movie_tableau_df = pd.read_csv('movie_visual.csv')
movie_tableau_df.head(5)
# Out:
#    Unnamed: 0                                              Title  Year  \
# 0       11757  Made in Germany - Die dramatische Geschichte d...  1957
# 1       14126                                     Kate & Leopold  2001
# 2       14424                                      Elephant Fury  1953
# 3       14756                        Mystery of the Black Jungle  1954
# 4       14818                        Another Time, Another Place  1983
#
#    Runtime(Min)                              Genres  AverageRating  NumVotes
# 0           101              ['Biography', 'Drama']            6.5        12
# 1           118    ['Comedy', 'Fantasy', 'Romance']            6.4     78045
# 2           100                    ['Drama', 'War']            4.2         6
# 3            80  ['Action', 'Adventure', 'Mystery']            5.4        34
# 4           118                    ['Drama', 'War']            6.5       256

# %%
#check type if index 0 exist
print (type(movie_tableau_df.loc[0, 'Genres']))
# Out:
# <class 'str'>

# %%
movie_tableau_df['Genres'] = movie_tableau_df['Genres'].apply(lambda x: x.replace('[','').replace(']',''))
movie_tableau_df.head(5)
# Out:
#    Unnamed: 0                                              Title  Year  \
# 0       11757  Made in Germany - Die dramatische Geschichte d...  1957
# 1       14126                                     Kate & Leopold  2001
# 2       14424                                      Elephant Fury  1953
# 3       14756                        Mystery of the Black Jungle  1954
# 4       14818                        Another Time, Another Place  1983
#
#    Runtime(Min)                            Genres  AverageRating  NumVotes
# 0           101              'Biography', 'Drama'            6.5        12
# 1           118    'Comedy', 'Fantasy', 'Romance'            6.4     78045
# 2           100                    'Drama', 'War'            4.2         6
# 3            80  'Action', 'Adventure', 'Mystery'            5.4        34
# 4           118                    'Drama', 'War'            6.5       256

# %%
movie_tableau_df = movie_tableau_df.explode('Genres')

# %%
movie_tableau_df.head(5)
# Out:
#    Unnamed: 0                                              Title  Year  \
# 0       11757  Made in Germany - Die dramatische Geschichte d...  1957
# 1       14126                                     Kate & Leopold  2001
# 2       14424                                      Elephant Fury  1953
# 3       14756                        Mystery of the Black Jungle  1954
# 4       14818                        Another Time, Another Place  1983
#
#    Runtime(Min)                            Genres  AverageRating  NumVotes
# 0           101              'Biography', 'Drama'            6.5        12
# 1           118    'Comedy', 'Fantasy', 'Romance'            6.4     78045
# 2           100                    'Drama', 'War'            4.2         6
# 3            80  'Action', 'Adventure', 'Mystery'            5.4        34
# 4           118                    'Drama', 'War'            6.5       256
